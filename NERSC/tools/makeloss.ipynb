# %%
file='4node_sum.txt'



with open(file) as f:
    for line in f:
        line=line.strip()
        if 'val_acc' in line:
            print(line)
# Out:
# ...
# 412416/412416 [==============================] - 769s 2ms/step - loss: 0.0051 - acc: 0.9984 - val_loss: 15.9351 - val_acc: 0.6214
